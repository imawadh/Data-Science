# %%
import pandas as pd

# %%
df = pd.read_csv('listings_summary.csv')

# %%
df
# Out:
#              id     scrape_id  last_scraped experiences_offered    host_id  \
# 0          2015  2.018110e+13         43411                none       2217
# 1          2695  2.018110e+13         43411                none       2986
# 2          3176  2.018110e+13         43411                none       3718
# 3          3309  2.018110e+13         43411                none       4108
# 4          7071  2.018110e+13         43411                none      17391
# ...         ...           ...           ...                 ...        ...
# 22547  29856708  2.018110e+13         43411                none   87555909
# 22548  29857108  2.018110e+13         43411                none   67537363
# 22549  29864272  2.018110e+13         43411                none    3146923
# 22550  29866805  2.018110e+13         43411                none   36961901
# 22551  29867352  2.018110e+13         43411                none  177464875
#
# ...

# %%
df.head()
# Out:
#      id     scrape_id  last_scraped experiences_offered  host_id host_name  \
# 0  2015  2.018110e+13         43411                none     2217       Ian
# 1  2695  2.018110e+13         43411                none     2986   Michael
# 2  3176  2.018110e+13         43411                none     3718    Britta
# 3  3309  2.018110e+13         43411                none     4108      Jana
# 4  7071  2.018110e+13         43411                none    17391    Bright
#
#    host_since                         host_location host_response_time  \
# 0  18-08-2008  Key Biscayne, Florida, United States     within an hour
# 1  16-09-2008               Berlin, Berlin, Germany                NaN
# 2  19-10-2008  Coledale, New South Wales, Australia       within a day
# 3  07-11-2008               Berlin, Berlin, Germany                NaN
# 4  16-05-2009               Berlin, Berlin, Germany     within an hour
#
#    host_response_rate  ...  review_scores_value requires_license  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22552 entries, 0 to 22551
# Data columns (total 76 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                22552 non-null  int64
#  1   scrape_id                         22552 non-null  float64
#  2   last_scraped                      22552 non-null  int64
#  3   experiences_offered               22552 non-null  object
#  4   host_id                           22552 non-null  int64
#  5   host_name                         22526 non-null  object
#  6   host_since                        22526 non-null  object
#  7   host_location                     22436 non-null  object
#  8   host_response_time                9658 non-null   object
#  9   host_response_rate                9657 non-null   float64
#  10  host_acceptance_rate              0 non-null      float64
# ...

# %%
df.shape
# Out:
# (22552, 76)

# %%
df.columns
# Out:
# Index(['id', 'scrape_id', 'last_scraped', 'experiences_offered', 'host_id',
#        'host_name', 'host_since', 'host_location', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'street',
#        'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet',
#        'price', 'weekly_price', 'monthly_price', 'security_deposit',
#        'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights',
#        'maximum_nights', 'calendar_updated', 'has_availability',
# ...

# %%
df.drop(['host_response_rate','jurisdiction_names'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22552 entries, 0 to 22551
# Data columns (total 74 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                22552 non-null  int64
#  1   scrape_id                         22552 non-null  float64
#  2   last_scraped                      22552 non-null  int64
#  3   experiences_offered               22552 non-null  object
#  4   host_id                           22552 non-null  int64
#  5   host_name                         22526 non-null  object
#  6   host_since                        22526 non-null  object
#  7   host_location                     22436 non-null  object
#  8   host_response_time                9658 non-null   object
#  9   host_acceptance_rate              0 non-null      float64
#  10  host_is_superhost                 22526 non-null  object
# ...

# %%
df.isnull()
# Out:
#           id  scrape_id  last_scraped  experiences_offered  host_id  \
# 0      False      False         False                False    False
# 1      False      False         False                False    False
# 2      False      False         False                False    False
# 3      False      False         False                False    False
# 4      False      False         False                False    False
# ...      ...        ...           ...                  ...      ...
# 22547  False      False         False                False    False
# 22548  False      False         False                False    False
# 22549  False      False         False                False    False
# 22550  False      False         False                False    False
# 22551  False      False         False                False    False
#
#        host_name  host_since  host_location  host_response_time  \
# 0          False       False          False               False
# ...

# %%
df.isnull()
# Out:
#           id  scrape_id  last_scraped  experiences_offered  host_id  \
# 0      False      False         False                False    False
# 1      False      False         False                False    False
# 2      False      False         False                False    False
# 3      False      False         False                False    False
# 4      False      False         False                False    False
# ...      ...        ...           ...                  ...      ...
# 22547  False      False         False                False    False
# 22548  False      False         False                False    False
# 22549  False      False         False                False    False
# 22550  False      False         False                False    False
# 22551  False      False         False                False    False
#
#        host_name  host_since  host_location  host_response_time  \
# 0          False       False          False               False
# ...

# %%
df.isnull().sum()
# Out:
# id                                     0
# scrape_id                              0
# last_scraped                           0
# experiences_offered                    0
# host_id                                0
#                                     ...
# cancellation_policy                    0
# require_guest_profile_picture          0
# require_guest_phone_verification       0
# calculated_host_listings_count         0
# reviews_per_month                   3914
# Length: 74, dtype: int64

# %%
df.isnull().sum().sort_values()
# Out:
# id                          0
# country_code                0
# country                     0
# latitude                    0
# longitude                   0
#                         ...
# host_response_time      12894
# weekly_price            18871
# monthly_price           19893
# square_feet             22106
# host_acceptance_rate    22552
# Length: 74, dtype: int64

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# host_acceptance_rate    22552
# square_feet             22106
# monthly_price           19893
# weekly_price            18871
# host_response_time      12894
#                         ...
# price                       0
# guests_included             0
# extra_people                0
# minimum_nights              0
# bed_type                    0
# Length: 74, dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 162936

# %%
round(df.isnull().sum().sort_values(ascending=False)*100/df.isnull().sum().sum(),2)
# Out:
# host_acceptance_rate    13.84
# square_feet             13.57
# monthly_price           12.21
# weekly_price            11.58
# host_response_time       7.91
#                         ...
# price                    0.00
# guests_included          0.00
# extra_people             0.00
# minimum_nights           0.00
# bed_type                 0.00
# Length: 74, dtype: float64

# %%
df.isnull().sum().sort_values(ascending=False)*100/df.shape[0]
# Out:
# host_acceptance_rate    100.000000
# square_feet              98.022348
# monthly_price            88.209471
# weekly_price             83.677723
# host_response_time       57.174530
#                            ...
# price                     0.000000
# guests_included           0.000000
# extra_people              0.000000
# minimum_nights            0.000000
# bed_type                  0.000000
# Length: 74, dtype: float64

# %%
numerical_columns =[]
non_numerical_columns = []

# %%
for i in df.columns:
    if (df[i].dtype=='int64' or df[i].dtype=='float'):
        numerical_columns.append(i)
    else:
        non_numerical_columns.append(i)

# %%
len(numerical_columns)
# Out:
# 34

# %%
len(non_numerical_columns)
# Out:
# 40

# %%
df.drop(columns=['host_acceptance_rate',
'square_feet','monthly_price','weekly_price'
,'host_response_time'],axis =  1, inplace=True)

# %%
df.shape
# Out:
# (22552, 69)

# %%
round(df.isnull().sum().sort_values(ascending=False)*100/df.isnull().sum().sum(),2)
# Out:
# security_deposit         14.05
# cleaning_fee             10.73
# host_neighbourhood        7.65
# review_scores_value       6.66
# review_scores_checkin     6.65
#                          ...
# guests_included           0.00
# extra_people              0.00
# minimum_nights            0.00
# maximum_nights            0.00
# id                        0.00
# Length: 69, dtype: float64
