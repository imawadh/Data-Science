# %%
print("Matplotlib")
# Out:
# Matplotlib

# %% [markdown]
# ### Anscombe Quartet --> Why do we need Data Visualistaion

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Define the data
data = {
    "x1": [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5],
    "y1": [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68],
    "x2": [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5],
    "y2": [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74],
    "x3": [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5],
    "y3": [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73],
    "x4": [8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8],
    "y4": [6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89],
}
print(data)
# Out:
# {'x1': [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5], 'y1': [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68], 'x2': [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5], 'y2': [9.14, 8.14, 8.74, 8.77, 9.26, 8.1, 6.13, 3.1, 9.13, 7.26, 4.74], 'x3': [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5], 'y3': [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73], 'x4': [8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8], 'y4': [6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.5, 5.56, 7.91, 6.89]}

# %%
data = pd.DataFrame(data)
plt.plot(data["x1"],data["y1"],marker='o')
plt.grid(True)
plt.xlabel("X1")
plt.ylabel("Y1")
plt.title("Chart og X1 and Y1")
plt.show()

# %%
print(data)
# data.transpose()
data = pd.DataFrame(data)
for i in range(1,5):
    x_label = f'x{i}'
    y_label = f'y{i}'
    print(x_label)
    print(y_label)
    plt.plot(data[x_label],data[y_label],marker='o',color="red")
    plt.show()
# Out:
#     x1     y1  x2    y2  x3     y3  x4     y4
# 0   10   8.04  10  9.14  10   7.46   8   6.58
# 1    8   6.95   8  8.14   8   6.77   8   5.76
# 2   13   7.58  13  8.74  13  12.74   8   7.71
# 3    9   8.81   9  8.77   9   7.11   8   8.84
# 4   11   8.33  11  9.26  11   7.81   8   8.47
# 5   14   9.96  14  8.10  14   8.84   8   7.04
# 6    6   7.24   6  6.13   6   6.08   8   5.25
# 7    4   4.26   4  3.10   4   5.39  19  12.50
# 8   12  10.84  12  9.13  12   8.15   8   5.56
# 9    7   4.82   7  7.26   7   6.42   8   7.91
# 10   5   5.68   5  4.74   5   5.73   8   6.89
# x1
# y1
# x2
# y2
# x3
# y3
# x4
# y4

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Convert dictionary to DataFrame
data = pd.DataFrame(data)

# Loop through the 4 datasets (i from 1 to 4)
for i in range(1, 5):
    x_col = f'x{i}'
    y_col = f'y{i}'
    plt.plot(data[x_col], data[y_col], marker='o', label=f'Dataset {i}')
    plt.title(f"Anscombe's Dataset {i}")
    plt.xlabel(x_col)
    plt.ylabel(y_col)
    plt.grid(True)
    plt.show()
